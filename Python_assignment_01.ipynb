# %% [markdown]
# <a href="https://colab.research.google.com/github/noorhameednoorhameed82-tech/Python-assignments/blob/main/Python_assignment_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Python Programming
# #Variables and data types :
#
#
# **This report is based on Python programming.**
#
# *The purpose of this assignment is to understand variables and basic data types in Python*

# %% [markdown]
# ### Q1. What is a variable?
# *A variable is a container used to store data values in Python.*
# **Example:**
# x = 10

# %% [markdown]
# ### Q2. Rules of Variable Naming
# 1. **Variable name must start with a letter or underscore**
# 2. **It cannot start with a number**
# 3. **No spaces allowed.**

# %% [markdown]
# ### Q3. Integer Data Type
# *Integer is a whole number without decimal.*
# **Example:**
# num = 5

# %% [markdown]
# ### Q4. Float Data Type
# *Float is a number with decimal.*
#
# **Example:**
# price = 10.5

# %% [markdown]
# ### Q5. String Data Type
# *String is a collection of characters.*
#
# **Examples:**
# name = "noor"

# %% [markdown]
# ### Q7. type() Function
# *#type() is used to check the data type of a variable.*

# %%
x = 10
print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# ###Q8. input() Function
# * input() function is used to take input from the user.*
# *The default data type of input() is string.*
# user_name = input("Enter your name: ")
# print("Your name is:", user_name)

# %% [markdown]
# ### Q9. Type Casting
# Type casting converts one data type into another.
# **Example:**
# num = int("5")

# %% [markdown]
# ### Q10. Program
# num = input("Enter a number: ")
# print(type(num))

# %%
num = input("Enter a number: ")
print(type(num))
# Out:
# Enter a number: 4
# <class 'str'>

# %% [markdown]
# #Conclusion:
# *In this assignment, we learned about variables
# and basic data types in Python. This knowledge is important*
